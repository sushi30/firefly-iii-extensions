# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib notebook

# %%
sns.set()

# %%
def annuity(c, t, r):
    return c * ((1 - (1 / (1 + r) ** t)) / r)


def required_cash_flow(FV, t, r):
    return FV / sum(map(lambda x: (1 + r) ** x, range(t + 1)))


def future_value(c, t, r):
    return c * sum(map(lambda x: (1 + r) ** x, range(t + 1)))


def commas(x):
    return "{:,}".format(x)

# %%
r = 1.04 ** (1 / 12) - 1
retiring_age = 62
pension_payment = 16_000
life_expectancy = 95

# %%
required = annuity(pension_payment, (life_expectancy - retiring_age) * 12, r)
print("required assets at retirement:", commas((round(required))))

for i in [30, 35, 40]:
    start_saving = i
    print("start saving at {}: ".format(i), end="")
    print(
        commas(
            round(required_cash_flow(required, (retiring_age - start_saving) * 12, r))
        )
    )
# Out:
# required assets at retirement: 3,547,775
# start saving at 30: 4,610
# start saving at 35: 6,136
# start saving at 40: 8,430

# %%
plt.plot(
    list(range(30, 45)),
    [required_cash_flow(required, (retiring_age - i) * 12, r) for i in range(30, 45)],
)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
